# %%
a={}
b={7:89,5.6:6.8,'as':'askdj',3_9J:4_7J,True:False,True:9}

# %%
type(a)
type(b)
# Out:
# dict

# %%
b
# Out:
# {7: 89, 5.6: 6.8, 'as': 'askdj', 39j: 47j, True: 9}

# %%
b.keys()
# Out:
# dict_keys([7, 5.6, 'as', 39j, True])

# %%
b.values()
# Out:
# dict_values([89, 6.8, 'askdj', 47j, 9])

# %%
b.items()
# Out:
# dict_items([(7, 89), (5.6, 6.8), ('as', 'askdj'), (39j, 47j), (True, 9)])

# %%
a.update(b)

# %%
a
# Out:
# {7: 89, 5.6: 6.8, 'as': 'askdj', 39j: 47j, True: 9}

# %%
a.pop('as')
# Out:
# 'askdj'

# %%
a
# Out:
# {7: 89, 5.6: 6.8, 39j: 47j, True: 9}

# %%
a.popitem()
# Out:
# (True, 9)

# %%
a
# Out:
# {7: 89, 5.6: 6.8, 39j: 47j}

# %%
a[7]
# Out:
# 89
