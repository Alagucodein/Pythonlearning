# %% [markdown]
# <a href="https://colab.research.google.com/github/Alagucodein/Pythonlearning/blob/main/Data_pre_processing_energy_efficiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e7f7403-9c41-45e4-8d46-e51768b30544" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e7f7403-9c41-45e4-8d46-e51768b30544">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("energy_efficiency.xlsx")

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %% [markdown]
# #Data Pre-Processing

# %%
df.shape
# Out:
# (768, 10)

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.tail()
# Out:
#        X1     X2     X3     X4   X5  X6   X7  X8     Y1     Y2
# 763  0.64  784.0  343.0  220.5  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.5  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.5  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.5  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.5  3.5   5  0.4   5  16.64  16.03

# %%
df.iloc[345:350]
# Out:
#        X1     X2     X3     X4   X5  X6    X7  X8     Y1     Y2
# 345  0.86  588.0  294.0  147.0  7.0   3  0.25   2  29.87  27.89
# 346  0.86  588.0  294.0  147.0  7.0   4  0.25   2  29.27  29.90
# 347  0.86  588.0  294.0  147.0  7.0   5  0.25   2  28.40  34.52
# 348  0.82  612.5  318.5  147.0  7.0   2  0.25   2  25.74  28.27
# 349  0.82  612.5  318.5  147.0  7.0   3  0.25   2  25.98  26.96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307195   24.587760
# std      0.133221    1.55096   10.090204    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# ...

# %% [markdown]
# #Data Cleaning.....

# %%
df1 = df.copy()

# %%
df1
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df1.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %% [markdown]
# #No Null values, so not required to clean
# # Data Encoding - All int and float values, so not required to encode

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %% [markdown]
# # x,y split

# %%
x = df1.iloc[:,:]

# %%
x
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
y = df.iloc[:,:]

# %%
y
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 1234)

# %%
x_train.shape
# Out:
# (614, 10)

# %%
y_train.shape
# Out:
# (614, 10)

# %% [markdown]
# # Model building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # model Evaluatation

# %%
y_predict = lr.predict(x_test)

# %%
y_predict
# Out:
# array([[ 8.60000000e-01,  5.88000000e+02,  2.94000000e+02, ...,
#          4.00000000e+00,  2.64400000e+01,  2.71700000e+01],
#        [ 6.40000000e-01,  7.84000000e+02,  3.43000000e+02, ...,
#         -1.04290811e-14,  1.08500000e+01,  1.67800000e+01],
#        [ 9.00000000e-01,  5.63500000e+02,  3.18500000e+02, ...,
#          3.00000000e+00,  3.50500000e+01,  3.38200000e+01],
#        ...,
#        [ 9.00000000e-01,  5.63500000e+02,  3.18500000e+02, ...,
#          2.00000000e+00,  3.56900000e+01,  4.06600000e+01],
#        [ 8.20000000e-01,  6.12500000e+02,  3.18500000e+02, ...,
#          3.00000000e+00,  2.54800000e+01,  2.77600000e+01],
#        [ 6.60000000e-01,  7.59500000e+02,  3.18500000e+02, ...,
#          4.00000000e+00,  1.14400000e+01,  1.48600000e+01]])

# %%
y_test
# Out:
#        X1     X2     X3      X4   X5  X6    X7  X8     Y1     Y2
# 200  0.86  588.0  294.0  147.00  7.0   2  0.10   4  26.44  27.17
# 40   0.64  784.0  343.0  220.50  3.5   2  0.00   0  10.85  16.78
# 630  0.90  563.5  318.5  122.50  7.0   4  0.40   3  35.05  33.82
# 356  0.76  661.5  416.5  122.50  7.0   2  0.25   2  36.95  36.87
# 305  0.79  637.0  343.0  147.00  7.0   3  0.25   1  40.03  37.81
# ..    ...    ...    ...     ...  ...  ..   ...  ..    ...    ...
# 288  0.98  514.5  294.0  110.25  7.0   2  0.25   1  28.15  29.79
# 175  0.71  710.5  269.5  220.50  3.5   5  0.10   3  10.70  13.87
# 583  0.90  563.5  318.5  122.50  7.0   5  0.40   2  35.69  40.66
# 397  0.82  612.5  318.5  147.00  7.0   3  0.25   3  25.48  27.76
# 228  0.66  759.5  318.5  220.50  3.5   2  0.10   4  11.44  14.86
#
# [154 rows x 10 columns]

# %%
error = y_predict - y_test

# %%
error
# Out:
#                X1            X2            X3            X4            X5  \
# 200  7.771561e-16  0.000000e+00  0.000000e+00 -2.842171e-14  1.776357e-15
# 40   6.661338e-16 -1.136868e-13  5.684342e-14  1.705303e-13 -4.440892e-16
# 630 -2.220446e-16  1.136868e-13  0.000000e+00 -5.684342e-14 -1.776357e-15
# 356  2.220446e-16  0.000000e+00 -5.684342e-14  7.105427e-14 -7.105427e-15
# 305  1.665335e-15  0.000000e+00 -5.684342e-14  2.842171e-14 -1.776357e-15
# ..            ...           ...           ...           ...           ...
# 288  0.000000e+00  1.136868e-13 -5.684342e-14 -1.136868e-13  0.000000e+00
# 175  1.110223e-15 -1.136868e-13  1.136868e-13  1.136868e-13  3.552714e-15
# 583 -5.551115e-16  1.136868e-13  0.000000e+00 -4.263256e-14  8.881784e-16
# 397 -1.443290e-15  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 228  7.771561e-16 -1.136868e-13  1.136868e-13  1.421085e-13 -4.440892e-16
#
#                X6            X7            X8            Y1            Y2
# ...

# %% [markdown]
# # find mean obsolute error and mean squared error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae = mean_absolute_error(y_test,y_predict)
mse = mean_squared_error(y_test,y_predict)

# %%
mae
# Out:
# 3.229420069306695e-14

# %%
mse
# Out:
# 3.2530914456230315e-27
