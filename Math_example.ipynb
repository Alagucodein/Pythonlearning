# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.floor(5.67)
# Out:
# 5

# %%
math.ceil(5,67)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f54d4c88571f> in <cell line: 1>()
# ----> 1 math.ceil(5,67)
#
# TypeError: math.ceil() takes exactly one argument (2 given)

# %%
math.factorial(7)
# Out:
# 5040

# %%
math.fabs(-7.50)
# Out:
# 7.5

# %%
math.modf(-3.14)
# Out:
# (-0.14000000000000012, -3.0)

# %%
math.fmod(24,5)
# Out:
# 4.0

# %%
math.exp(5)
# Out:
# 148.4131591025766

# %%
math.pow(10,2)
# Out:
# 100.0

# %%
math.sqrt(7)
# Out:
# 2.6457513110645907

# %%
math.sin(90)
# Out:
# 0.8939966636005579
