# %%
import numpy as np

# %%
t=np.array([8,6,7,4,5])

# %%
t.flatten()
# Out:
# array([8, 6, 7, 4, 5])

# %%
t[::-1]
# Out:
# array([5, 4, 7, 6, 8])

# %%
a = np.array([1,8,9,5])
b= np.array([2,5,6,8])

# %%
c = np.concatenate([a,b])

# %%
c
# Out:
# array([1, 8, 9, 5, 2, 5, 6, 8])

# %%
n=np.array([[2,4,5],[3,5,7]])
m=np.array([[3,5,6],[4,6,9],[2,7,0]])
o=np.concatenate([n,m])
o
# Out:
# array([[2, 4, 5],
#        [3, 5, 7],
#        [3, 5, 6],
#        [4, 6, 9],
#        [2, 7, 0]])

# %%
x= np.full([2,2],20, dtype= int)
y= np.full([2,2],5, dtype= int)
x
# Out:
# array([[20, 20],
#        [20, 20]])

# %%
x+=y

# %%
x
# Out:
# array([[30, 30],
#        [30, 30]])

# %%
x-y
# Out:
# array([[25, 25],
#        [25, 25]])

# %%
x*y
# Out:
# array([[150, 150],
#        [150, 150]])

# %%
x/y
# Out:
# array([[6., 6.],
#        [6., 6.]])

# %%
y.min()
# Out:
# 5

# %%
x.mean()
# Out:
# 30.0

# %%
d = np.std(y)

# %%
d
# Out:
# 0.0

# %%
y.T
# Out:
# array([[5, 5],
#        [5, 5]])
