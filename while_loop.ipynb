# %%
s=10
while s < 15:
  print('Hi ')
  s = s + 1
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
num = 0
while num < 101:
  print(num*7)
  num += 1
# Out:
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98
# 105
# 112
# 119
# 126
# 133
# 140
# 147
# 154
# 161
# 168
# 175
# 182
# 189
# 196
# 203
# 210
# 217
# 224
# 231
# 238
# 245
# 252
# 259
# 266
# 273
# 280
# 287
# 294
# 301
# 308
# 315
# 322
# 329
# 336
# 343
# 350
# 357
# 364
# 371
# 378
# 385
# 392
# 399
# 406
# 413
# 420
# 427
# 434
# 441
# 448
# 455
# 462
# 469
# 476
# 483
# 490
# 497
# 504
# 511
# 518
# 525
# 532
# 539
# 546
# 553
# 560
# 567
# 574
# 581
# 588
# 595
# 602
# 609
# 616
# 623
# 630
# 637
# 644
# 651
# 658
# 665
# 672
# 679
# 686
# 693
# 700

# %%
name_list = ['a','b','c','d','e']
i=0
while i < 5:
  print(name_list[i])
  i = i + 1
# Out:
# a
# b
# c
# d
# e

# %%
name_list = ['a','b','c','d','e']
for j in name_list:
  print(j,'Welcome to the class')
# Out:
# a Welcome to the class
# b Welcome to the class
# c Welcome to the class
# d Welcome to the class
# e Welcome to the class

# %%
name_list = ['a','b','c','d','e']
k=0
while k<len(name_list):
  if(name_list[k] == 'c'):
    print(name_list[k],'Welcome to session')
    break
  else:
      print('bye')
      k=k+1
# Out:
# bye
# bye
# c Welcome to session

# %%
for n in "chennai":
  if(n == 'n'):
    continue
  print(n)
# Out:
# c
# h
# e
# a
# i

# %%
m=[5,7,8,9,6,8,9]
for p in m:
  if(p%2==0):
    print(p,'even')
  else:
      print(p,'odd')
p +=1
# Out:
# 5 odd
# 7 odd
# 8 even
# 9 odd
# 6 even
# 8 even
# 9 odd

# %%
year = int(input("Year : "))
while(year > 2000):
  if(year%4 == 0 or year % 100 ==0):
    print(year,"leap")
    break
  else:
    year += 1
# Out:
# Year : 2024
# 2024 leap

# %%
name=['ram','sam','rahul','vani']

# %%
studentNames = ['ram','sam','rahul','vani']
q = 0
while q < len(studentNames):
    print(" Student Name is " + studentNames[q] + " length is "+ str(len(studentNames[q])))
    q+=1
# Out:
#  Student Name is ram length is 3
#  Student Name is sam length is 3
#  Student Name is rahul length is 5
#  Student Name is vani length is 4

# %%
num = 10
num2= 10
while num > 5 and num2 > 5:
  num -= 2
  num -= 1
  print(num,num2)
# Out:
# 7 10
# 4 10
