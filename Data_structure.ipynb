# %%
s=[]

# %%
type(s)
# Out:
# list

# %%
s=[2,6,0,9,True,3_9j,'jsdhdas']
len(s)
# Out:
# 7

# %%
s[0:5]
# Out:
# [2, 6, 0, 9, True]

# %%
Ala=['Alagappan',43,55,True]

# %%
Ala.append(156)

# %%
print(Ala)
# Out:
# ['Alagappan', 43, 55, True, 156]

# %%
Ala.insert(3,'kannappan')

# %%
print(Ala)
# Out:
# ['Alagappan', 43, 55, 'kannappan', True, 156]

# %%
s=[2,6,0,9,True,3_9j,'jsdhdas',[223,23,'test']]

# %%
s
# Out:
# [2, 6, 0, 9, True, 39j, 'jsdhdas', [223, 23, 'test']]

# %%
s.extend([89,213,'extent'])

# %%
s
# Out:
# [2, 6, 0, 9, True, 39j, 'jsdhdas', [223, 23, 'test'], 89, 213, 'extent']

# %%
s.pop(6)
# Out:
# 'jsdhdas'

# %%
s
# Out:
# [2, 6, 0, 9, True, 39j, [223, 23, 'test'], 89, 213, 'extent']

# %%
s.remove(39j)

# %%
s
# Out:
# [2, 6, 0, 9, True, [223, 23, 'test'], 89, 213, 'extent']

# %%
s.count(9)
# Out:
# 1

# %%
len(s)
# Out:
# 9

# %%
T=[2, 6, 0, 9, True, 89, 213]

# %%
T.sort()

# %%
T
# Out:
# [0, True, 2, 6, 9, 89, 213]

# %%
T.clear()

# %%
T
# Out:
# []
