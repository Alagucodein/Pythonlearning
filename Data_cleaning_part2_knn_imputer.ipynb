# %% [markdown]
# <a href="https://colab.research.google.com/github/Alagucodein/Pythonlearning/blob/main/Data_cleaning_part2_knn_imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1ee5414-4bef-4c7a-818a-1e1b5dbdc987" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1ee5414-4bef-4c7a-818a-1e1b5dbdc987">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('loan_small.csv')

# %%
df.shape
# Out:
# (16, 7)

# %%
df.head()
# Out:
#     Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0  LP001002     NaN           5849.0                0.0         NaN  urban
# 1  LP001003    Male           4583.0                NaN       128.0   semi
# 2  LP001005    Male           3000.0                0.0        66.0    NaN
# 3  LP001006  Female           2583.0             2358.0       120.0   semi
# 4  LP001008    Male              NaN                0.0       141.0  urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3         NaN
# 4           Y

# %%
df.tail()
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 12  LP001028  Female              NaN             8106.0         NaN  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 11           Y
# 12           Y
# 13           N
# 14           Y
# 15           Y

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count        14.000000          15.000000   13.000000
# mean       4103.571429        2509.333333  140.923077
# std        2858.096481        3147.982090   86.032418
# min        1299.000000           0.000000   17.000000
# 25%        2520.750000         350.000000  109.000000
# 50%        3118.000000        1526.000000  125.000000
# 75%        4858.250000        2672.000000  158.000000
# max       12841.000000       10968.000000  349.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %%
df1 = df.copy()

# %%
from sklearn.impute import KNNImputer

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, 5]
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Create a KNN imputer object
imputer = KNNImputer(n_neighbors=2)

# Fit the imputer to the data and transform it
imputed_data = imputer.fit_transform(df)

# Convert the imputed data back to a DataFrame
imputed_df = pd.DataFrame(imputed_data, columns=df.columns)

print("\nImputed DataFrame:")
print(imputed_df)
# Out:
# Original DataFrame:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  2.0
# 2  NaN  3.0  3.0
# 3  4.0  4.0  NaN
# 4  5.0  5.0  5.0
#
# Imputed DataFrame:
#      A    B    C
# 0  1.0  2.5  1.0
# 1  2.0  2.0  2.0
# 2  3.0  3.0  3.0
# 3  4.0  4.0  4.0
# 4  5.0  5.0  5.0

# %%
from sklearn.impute import SimpleImputer
sm = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
sm.fit_transform(df1)
# Out:
# array([['LP001002', 'Male', 5849.0, 0.0, 17.0, 'urban', 'Y'],
#        ['LP001003', 'Male', 4583.0, 0.0, 128.0, 'semi', 'N'],
#        ['LP001005', 'Male', 3000.0, 0.0, 66.0, 'semi', 'Y'],
#        ['LP001006', 'Female', 2583.0, 2358.0, 120.0, 'semi', 'Y'],
#        ['LP001008', 'Male', 1299.0, 0.0, 141.0, 'urban', 'Y'],
#        ['LP001011', 'Male', 5417.0, 4196.0, 267.0, 'semi', 'Y'],
#        ['LP001013', 'Male', 2333.0, 1516.0, 17.0, 'rural', 'Y'],
#        ['LP001014', 'Female', 3036.0, 2504.0, 158.0, 'semi', 'N'],
#        ['LP001018', 'Male', 4006.0, 1526.0, 168.0, 'rural', 'Y'],
#        ['LP001020', 'Male', 12841.0, 10968.0, 349.0, 'semi', 'N'],
#        ['LP001024', 'Female', 3200.0, 700.0, 70.0, 'urban', 'Y'],
#        ['LP001027', 'Male', 2500.0, 1840.0, 109.0, 'urban', 'Y'],
#        ['LP001028', 'Female', 1299.0, 8106.0, 17.0, 'urban', 'Y'],
#        ['LP001029', 'Male', 1853.0, 2840.0, 114.0, 'urban', 'N'],
# ...

# %%
df2 = df.copy()

# %%
df2
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
df2 = df.drop(['Loan_ID','Gender','Area','Loan_Status',],axis=1)

# %%
df2
# Out:
#     ApplicantIncome  CoapplicantIncome  LoanAmount
# 0            5849.0                0.0         NaN
# 1            4583.0                NaN       128.0
# 2            3000.0                0.0        66.0
# 3            2583.0             2358.0       120.0
# 4               NaN                0.0       141.0
# 5            5417.0             4196.0       267.0
# 6            2333.0             1516.0         NaN
# 7            3036.0             2504.0       158.0
# 8            4006.0             1526.0       168.0
# 9           12841.0            10968.0       349.0
# 10           3200.0              700.0        70.0
# 11           2500.0             1840.0       109.0
# 12              NaN             8106.0         NaN
# 13           1853.0             2840.0       114.0
# 14           1299.0             1086.0        17.0
# 15           4950.0                0.0       125.0

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
im = IterativeImputer(random_state=7)

# %%
df2_imp = im.fit_transform(df2)

# %%
df2_imp
# Out:
# array([[ 5849.        ,     0.        ,   139.59866278],
#        [ 4583.        ,  2780.94014351,   128.        ],
#        [ 3000.        ,     0.        ,    66.        ],
#        [ 2583.        ,  2358.        ,   120.        ],
#        [ 2353.342815  ,     0.        ,   141.        ],
#        [ 5417.        ,  4196.        ,   267.        ],
#        [ 2333.        ,  1516.        ,   108.00946073],
#        [ 3036.        ,  2504.        ,   158.        ],
#        [ 4006.        ,  1526.        ,   168.        ],
#        [12841.        , 10968.        ,   349.        ],
#        [ 3200.        ,   700.        ,    70.        ],
#        [ 2500.        ,  1840.        ,   109.        ],
#        [ 8519.17410286,  8106.        ,   271.62510655],
#        [ 1853.        ,  2840.        ,   114.        ],
#        [ 1299.        ,  1086.        ,    17.        ],
#        [ 4950.        ,     0.        ,   125.        ]])
