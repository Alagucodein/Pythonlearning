# %%
r={}

# %%
type(r)
# Out:
# dict

# %%
r={1,5,9,8}

# %%
type(r)
# Out:
# set

# %%
s={58,7,2,79,37}

# %%
s
# Out:
# {2, 7, 37, 58, 79}

# %%
m={156,454,8,'test',True,9.8,78.6,5_9j}

# %%
m
# Out:
# {156, 454, 59j, 78.6, 8, 9.8, True, 'test'}

# %%
m.add('sddsf')

# %%
m
# Out:
# {156, 454, 59j, 78.6, 8, 9.8, True, 'sddsf', 'test'}

# %%
a={1,3,5,7}
b={2,4,6,8,10}
c= a.union(b)
d= b.intersection(a)

# %%
c
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 10}

# %%
d
# Out:
# set()

# %%
name = 'Alagu'
if name == 'Alagu':
  print('ok')
else:
  print('no')
# Out:
# ok

# %%
age = int(input('Age:'))
if age>18:
  print('Eligible')
elif age==18:
  print('welcome')
else:
  print('not Eligible')
# Out:
# Age:18
# welcome

# %%
Mark1 = int(input('Mark 1:'))
Mark2 = int(input('Mark 2:'))
Mark3 = int(input('Mark 3:'))
Mark4 = int(input('Mark 4:'))
Pratical = 100
Avg = (Mark1 + Mark2 + Mark3 + Mark4 + Pratical)/5
if Avg >= 90:
  print('excelent')
elif Avg >= 80:
  print('good')
elif Avg >= 60:
  print('ok')
else:
  print('fail')
# Out:
# Mark 1:52
# Mark 2:56
# Mark 3:57
# Mark 4:32
# fail

# %%
a=(4,5,7,9)
for i in a:
  print(i)
else:
  print('end')
# Out:
# 4
# 5
# 7
# 9
# end

# %%
a='hello'
for i in a:
  print(i)
else:
  print('end')
# Out:
# h
# e
# l
# l
# o
# end

# %%
a=(1,2,3,4,5)
for i in a:
  print(i**7)
else:
  print('end')
# Out:
# 1
# 128
# 2187
# 16384
# 78125
# end
