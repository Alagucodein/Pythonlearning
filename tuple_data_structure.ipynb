# %%
b=(4,5,8,9,7)

# %%
type(b)
# Out:
# tuple

# %%
b
# Out:
# (4, 5, 8, 9, 7)

# %%
b.index(8)
# Out:
# 2

# %%
b.count(9)
# Out:
# 1

# %%
d=4,5,8,'sdfjdsf',True,1

# %%
type(d)
# Out:
# tuple

# %%
d
# Out:
# (4, 5, 8, 'sdfjdsf', True, 1)
